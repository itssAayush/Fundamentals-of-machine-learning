# %% [markdown]
# Array Creation

# %%
#create a id numpy array called cost price containing the price for 3 iteams [1500,3000,5000] then create a 2d NumPy print the shape and dimention of both arrays
import numpy as np
cost = np.array([1500,3000,5000])
print(cost)
# Out:
# [1500 3000 5000]
