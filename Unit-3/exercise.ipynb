# %%
import matplotlib.pyplot as plt

# Data
study_hours = [3,4,2,5,6,3,4,2,8,6,4,3,5,2,4,5,2,4,3,5]  # added one value
spotify_hours = [1,2,1,3,2,4,2,3,1,2,1,2,3,4,2,1,3,2,4,1]
screen_time = [5,6,7,8,9,6,7,8,9,7,6,7,8,9,7,6,8,9,7,6]
sleep_hours = [7,6,5,6,4,7,6,5,4,6,7,6,5,4,6,7,5,4,6,5]
gpa = [8.2,7.9,7.1,6.8,6.4,8.3,7.8,7.0,6.6,6.9,8.1,7.7,7.2,6.7,8.0,7.6,7.3,6.9,6.5,7.8]

# %%
# Scatter Plot
plt.figure()
plt.scatter(study_hours, gpa)
plt.title("Study Hours vs GPA")
plt.xlabel("Study Hours")
plt.ylabel("GPA")
plt.show()

# %%
# Histogram
plt.figure()
plt.hist(sleep_hours, bins=5)
plt.title("Distribution of Sleep Hours")
plt.xlabel("Sleep Hours")
plt.ylabel("Frequency")
plt.show()

# %%
# Line Plot
plt.figure()
plt.plot(screen_time, marker='o')
plt.title("Screen Time Pattern")
plt.xlabel("Student ID")
plt.ylabel("Screen Time (hours)")
plt.show()
