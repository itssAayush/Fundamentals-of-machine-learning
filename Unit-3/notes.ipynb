# %% [markdown]
# The standard deviation tells us the typical distance of data points from the mean.
# 1. Low :Data is consistent and bunched near the center
# 2. High: Data is not consistent and spread far from the center

# %% [markdown]
# The Z score: The outlier detector

# %% [markdown]
# Correlation coefficient(r)
