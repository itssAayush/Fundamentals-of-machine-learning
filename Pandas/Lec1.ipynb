# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Series in Pandas

# %%
s = pd.Series([10, 20, 30, 40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# SERIES FROM DICTIONARY

# %%
data = {
    "a": 10,
    "b": 20,
    "c": 30
}

s = pd.Series(data)

print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# DataFrames in Pandas

# %%
data = {
    "Name": ["Aman", "krish", "karan"],
    "Age": [22, 23, 21],
    "Marks": [85, 90, 88]
}

# %%
print(data)
# Out:
# {'Name': ['Aman', 'krish', 'karan'], 'Age': [22, 23, 21], 'Marks': [85, 90, 88]}

# %%
type(data)
# Out:
# dict

# %%
marks = pd.DataFrame(data)

# %%
print(marks)
# Out:
#     Name  Age  Marks
# 0   Aman   22     85
# 1  krish   23     90
# 2  karan   21     88

# %%
marks = pd.DataFrame(
    data, 
    index =["Student1", "Student2", "Student3"],
)

# %%
print(marks)
# Out:
#            Name  Age  Marks
# Student1   Aman   22     85
# Student2  krish   23     90
# Student3  karan   21     88

# %%
marks.set_index("Name", inplace=True) # if we are setting iplace = true it means we are changing the original object itself.

# %%
print(marks)
# Out:
#        Age  Marks
# Name
# Aman    22     85
# krish   23     90
# karan   21     88

# %%
df = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace", "Hannah", "Ian", "Jack"],
    "Age": [12, 23, 4, 19, 21, 18, 25, 17, 20, 22],
    "Marks": [43, 90, 41, 92, 47, 38, 45, 89, 42, 40]
})


print(df)
# Out:
#       Name  Age  Marks
# 0    Alice   12     43
# 1      Bob   23     90
# 2  Charlie    4     41
# 3    David   19     92
# 4      Eva   21     47
# 5    Frank   18     38
# 6    Grace   25     45
# 7   Hannah   17     89
# 8      Ian   20     42
# 9     Jack   22     40

# %%
df.head() # as the no of rows is less than 5 so the output of both df head and df tail will be identical
# Out:
#       Name  Age  Marks
# 0    Alice   12     43
# 1      Bob   23     90
# 2  Charlie    4     41
# 3    David   19     92
# 4      Eva   21     47

# %%
df.tail() # as the no of rows is less than 5 so the output of both df head and df tail will be identical
# Out:
#      Name  Age  Marks
# 5   Frank   18     38
# 6   Grace   25     45
# 7  Hannah   17     89
# 8     Ian   20     42
# 9    Jack   22     40

# %%
df.describe()
# Out:
#              Age      Marks
# count  10.000000  10.000000
# mean   18.100000  56.700000
# std     6.118279  23.352611
# min     4.000000  38.000000
# 25%    17.250000  41.250000
# 50%    19.500000  44.000000
# 75%    21.750000  78.500000
# max    25.000000  92.000000

# %% [markdown]
# Selecting the data

# %%
df["Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eva
# 5      Frank
# 6      Grace
# 7     Hannah
# 8        Ian
# 9       Jack
# Name: Name, dtype: object

# %% [markdown]
# Filtering in Pandas

# %%
df[df["Marks"] > 85]
# Out:
#      Name  Age  Marks
# 1     Bob   23     90
# 3   David   19     92
# 7  Hannah   17     89

# %%
#multiple conditions

df[(df["Age"]>21)&(df["Marks"]>85)]
# Out:
#   Name  Age  Marks
# 1  Bob   23     90

# %%
df.sort_values("Marks")
# Out:
#       Name  Age  Marks
# 5    Frank   18     38
# 9     Jack   22     40
# 2  Charlie    4     41
# 8      Ian   20     42
# 0    Alice   12     43
# 6    Grace   25     45
# 4      Eva   21     47
# 7   Hannah   17     89
# 1      Bob   23     90
# 3    David   19     92

# %%
df.sort_values("Marks", ascending=False)
# Out:
#       Name  Age  Marks
# 3    David   19     92
# 1      Bob   23     90
# 7   Hannah   17     89
# 4      Eva   21     47
# 6    Grace   25     45
# 0    Alice   12     43
# 8      Ian   20     42
# 2  Charlie    4     41
# 9     Jack   22     40
# 5    Frank   18     38

# %%
df["Age"].value_counts()
# Out:
# Age
# 12    1
# 23    1
# 4     1
# 19    1
# 21    1
# 18    1
# 25    1
# 17    1
# 20    1
# 22    1
# Name: count, dtype: int64

# %%
import pandas as pd
